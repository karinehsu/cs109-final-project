# %%
import numpy as np
import pandas as pd
import pdb
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Read in throw-by-throw raw data

# %%
# %%bash
# ls
# Out:
# DCBreeze2015-stats.csv
# explore_sjs.ipynb
# MadisonRadicals2015-stats.csv
# NewYorkEmpire2015-stats.csv
# SanJoseSpiders2015-stats.csv

# %%
sjs = pd.read_csv("SanJoseSpiders2015-stats.csv")

# %%
sjs.head(3)
# Out:
#           Date/Time Tournamemnt              Opponent  Point Elapsed Seconds  \
# 0  2015-05-03 13:36        AUDL  Los Angeles Aviators                     51
# 1  2015-05-03 13:36        AUDL  Los Angeles Aviators                     51
# 2  2015-05-03 13:36        AUDL  Los Angeles Aviators                     51
#
#   Line  Our Score - End of Point  Their Score - End of Point Event Type  \
# 0    O                         1                           0    Offense
# 1    O                         1                           0    Offense
# 2    O                         1                           0    Offense
#
#          Action     Passer   Receiver Defender  Hang Time (secs)  Player 0  \
# 0  OpponentPull  Anonymous  Anonymous      NaN               NaN  Rasmus C
# 1         Catch   Rasmus C    Wynne R      NaN               NaN  Rasmus C
# 2         Catch    Wynne R   Rasmus C      NaN               NaN  Rasmus C
#
#    Player 1 Player 2  Player 3  Player 4 Player 5  Player 6 Player 7 Player 8  \
# 0  Sanche M  Wynne R  Kittre B  Higgin S  Smith K  Johnso C      NaN      NaN
# 1  Sanche M  Wynne R  Kittre B  Higgin S  Smith K  Johnso C      NaN      NaN
# 2  Sanche M  Wynne R  Kittre B  Higgin S  Smith K  Johnso C      NaN      NaN
#
#   Player 9 Player 10 Player 11  Player 12  Player 13  Player 14  Player 15  \
# 0      NaN       NaN       NaN        NaN        NaN        NaN        NaN
# 1      NaN       NaN       NaN        NaN        NaN        NaN        NaN
# 2      NaN       NaN       NaN        NaN        NaN        NaN        NaN
#
#    Player 16  Player 17  Player 18  Player 19  Player 20  Player 21  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
#
#    Player 22  Player 23  Player 24  Player 25  Player 26  Player 27  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
#
#    Elapsed Time (secs)
# 0                    0
# 1                    9
# 2                   13

# %% [markdown]
# ### Get all players who played a point

# %%
cleaned = sjs[pd.isnull(sjs["Player 1"]) == False]
players = pd.unique(cleaned.loc[0:, "Player 0":"Player 27"].values.ravel())
players = [player for player in players if str(player) != "nan"]
players
# Out:
# ['Rasmus C',
#  'Sanche M',
#  'Wynne R',
#  'Kittre B',
#  'Higgin S',
#  'Smith K',
#  'Johnso C',
#  'Jaffe M',
#  'Peters B',
#  'Falat E',
#  'Cocks K',
#  'Dillow L',
#  'Marcy J',
#  'Farina C',
#  'Crawfo M',
#  'Cohen G',
#  'Natali M',
#  'Ham S',
#  'Norden J',
#  'Cao C',
#  'Zaccar S',
#  'Grant T',
#  'Klevec A',
#  'Brown A',
#  'Guerre X',
#  'Joye A',
#  'Reinha S',
#  'Van Ar K',
#  'Roeder S']

# %% [markdown]
# ### Looking at point-by-point summary statistics

# %%
# throws where a goal was scored
goals = sjs[sjs["Action"] == "Goal"]
scores = goals[goals["Event Type"] == "Offense"]
goals.head(3)
# Out:
#            Date/Time Tournamemnt              Opponent  Point Elapsed Seconds  \
# 11  2015-05-03 13:36        AUDL  Los Angeles Aviators                     51
# 20  2015-05-03 13:36        AUDL  Los Angeles Aviators                     58
# 30  2015-05-03 13:36        AUDL  Los Angeles Aviators                     85
#
#    Line  Our Score - End of Point  Their Score - End of Point Event Type  \
# 11    O                         1                           0    Offense
# 20    D                         2                           0    Offense
# 30    D                         3                           0    Offense
#
#    Action    Passer  Receiver Defender  Hang Time (secs)  Player 0  Player 1  \
# 11   Goal  Higgin S   Wynne R      NaN               NaN  Rasmus C  Sanche M
# 20   Goal  Johnso C  Kittre B      NaN               NaN  Rasmus C   Jaffe M
# 30   Goal  Dillow L   Cohen G      NaN               NaN  Dillow L   Marcy J
#
#     Player 2  Player 3  Player 4  Player 5  Player 6 Player 7 Player 8  \
# 11   Wynne R  Kittre B  Higgin S   Smith K  Johnso C      NaN      NaN
# 20  Peters B   Falat E  Kittre B   Cocks K  Johnso C      NaN      NaN
# 30  Farina C  Crawfo M   Cohen G  Natali M     Ham S      NaN      NaN
#
#    Player 9 Player 10 Player 11  Player 12  Player 13  Player 14  Player 15  \
# 11      NaN       NaN       NaN        NaN        NaN        NaN        NaN
# 20      NaN       NaN       NaN        NaN        NaN        NaN        NaN
# 30      NaN       NaN       NaN        NaN        NaN        NaN        NaN
#
#     Player 16  Player 17  Player 18  Player 19  Player 20  Player 21  \
# 11        NaN        NaN        NaN        NaN        NaN        NaN
# 20        NaN        NaN        NaN        NaN        NaN        NaN
# 30        NaN        NaN        NaN        NaN        NaN        NaN
#
#     Player 22  Player 23  Player 24  Player 25  Player 26  Player 27  \
# 11        NaN        NaN        NaN        NaN        NaN        NaN
# 20        NaN        NaN        NaN        NaN        NaN        NaN
# 30        NaN        NaN        NaN        NaN        NaN        NaN
#
#     Elapsed Time (secs)
# 11                   49
# 20                  165
# 30                  305

# %% [markdown]
# The Spiders score about 68% of their points starting on O line. That's almost a third of their points from breaks.

# %%
len(scores["Line"][scores["Line"] == "O"]) / float(scores.shape[0])
# Out:
# 0.6813725490196079

# %% [markdown]
# Let's look at their O and D line convesion rates

# %%
o_line = goals[goals["Line"] == "O"]
broken = o_line["Event Type"][o_line["Event Type"] == "Defense"]
print "Broken", broken.shape[0], "points out of", o_line.shape[0]
print broken.shape[0] / float(o_line.shape[0])
# Out:
# Broken 93 points out of 371
# 0.250673854447

# %% [markdown]
# Interestingly, they are broken on about 25% of their O line posessions. I would have expected much lower.

# %%
d_line = goals[goals["Line"] == "D"]
breaks = d_line["Event Type"][d_line["Event Type"] == "Offense"]
print "The Spiders broke on", breaks.shape[0], "out of", d_line.shape[0]
print breaks.shape[0] / float(d_line.shape[0])
# Out:
# The Spiders broke on 130 out of 410
# 0.317073170732

# %% [markdown]
# They broke on about 31% of their D points, and also had ~40 more D points than O points. A 30% break percentage seems pretty good to me.

# %% [markdown]
# Let's get some player-specific summary statistics

# %%
stat_dict = {"goals": 0, "assists": 0, "ds": 0, "throwaways": 0, "drops": 0}
sjs_dict = {player : dict(stat_dict) for player in players}

# col 9 = thrower, 10 = receiver
o_goals = goals[goals["Event Type"] == "Offense"]
for x in o_goals.values:
    sjs_dict[x[9]]["assists"] += 1
    sjs_dict[x[10]]["goals"]  += 1
    
# add D's to dict
ds = sjs[sjs["Action"] == "D"]
for x in ds.values:
    sjs_dict[x[11]]["ds"] += 1
    
# add turnovers to dict
turns = sjs[((sjs.Action == "Throwaway") | (sjs.Action == "Drop")) & (sjs["Event Type"] == "Offense")]
for x in turns.values:
    if x[8] == "Throwaway":
        sjs_dict[x[9]]["throwaways"] += 1
    else:
        sjs_dict[x[10]]["drops"]     += 1

# %%
pd.DataFrame.from_dict(sjs_dict, orient="index").sort_values("ds", ascending=False)
# Out:
#           drops  throwaways  goals  assists  ds
# Kittre B      3          23     68       37  26
# Sanche M      4          25     38       46  17
# Wynne R       0           9     14        9  15
# Cohen G       0           9     26       15  14
# Joye A        3          29     15       45  11
# Peters B      0          12     10        4  10
# Grant T       1          15      9       15   9
# Smith K       0          27      4       35   9
# Higgin S      3          24     46       38   8
# Johnso C      4          20     29       29   8
# Van Ar K      1           5     11        5   6
# Rasmus C      2          29     22       18   6
# Jaffe M       0           4      3        5   6
# Crawfo M      0           7      8       11   5
# Cao C         2          13     12       26   5
# Cocks K       4          12      9        8   5
# Marcy J       1          11      5       18   5
# Natali M      0           2      5        2   5
# Falat E       1           4      4        3   3
# Norden J      1          14      5       13   3
# Reinha S      0           0      4        1   2
# Zaccar S      1           8      1        8   2
# Ham S         4           5     51        9   2
# Farina C      0          10      1        2   1
# Dillow L      0           6      4        3   1
# Klevec A      1           0      0        0   0
# Roeder S      1           2      2        1   0
# Guerre X      1           1      1        2   0
# Brown A       0           0      1        0   0

# %%
pd.unique(sjs["Action"])
# Out:
# array(['OpponentPull', 'Catch', 'Goal', 'Pull', 'Throwaway', 'PullOb', 'D',
#        'Drop', 'EndOfFirstQuarter', 'OpponentPullOb', 'Halftime',
#        'MiscPenalty', 'EndOfThirdQuarter', 'Stall', 'GameOver',
#        'EndOfFourthQuarter'], dtype=object)
